# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

'''
ACDH
I M Velicer
1 Aug 2018
'''
 
#generate combined data tables 

df1 = pd.read_csv('/Volumes/IMVDrive/cfdb-django/data/tablets.csv', usecols=['title', 'region', 'period', 'Year', 'scribe'], engine='python')
df2 = pd.read_csv('/Volumes/IMVDrive/cfdb-django/data/glyphs.csv', usecols=['tablet', 'sign', 'image'], engine='python')
df3 = pd.read_csv('/Volumes/IMVDrive/cfdb-django/data/stdSigns.csv', usecols=['sign_name', 'image'], engine='python')

df4 = df1.merge(df2, left_on='title', right_on='tablet', how='right')
df5 = df4.drop(['tablet'], axis=1)

df6 = df5.merge(df3, left_on='sign', right_on='sign_name', how='right')
df7 = df6.drop(['sign_name'], axis=1)
df8 = df7.rename(index=str, columns={"title": "tablet", "Year": "year", "image_x": "glyph", "image_y": "std_sign"})
df9 = df8.sort_values('std_sign')
df9
# Out:
#           tablet    region                                             scribe  \
# 6280    YBC 3504      Uruk                                                n/a
# 6287    BM 95512   Babylon                                                n/a
# 6286   YOS 6 155      Uruk                       Nādinu/Bēl-ahhē-iqīša//Egibi
# 6285  YOS 21 198      Uruk                                                n/a
# 6284   CT 49 159   Babylon                                                n/a
# 6283   YOS 6 100      Uruk           Šamaš-zēru-iddin/Bēl-ahu-iddin//Mukallim
# 6282   YBC 11390      Uruk                          Širikti-Marduk/Ibni-Ištar
# 6281    BM 87228   Babylon                                   [x]/Nabû-ittannu
# 6279   YOS 19 76      Uruk  Innin-šumu-uṣur/Nergal-ušēzib//Kidin-MardukŠum...
# 1237    BM 25625  Borsippa  Nabû-zēru-līšir/Nabû-zēru-iddini//Iddin-Papsukkal
# 1236    BM 42340    Sippar                        Balāṭu/Bēl-rēmanni//Sîn-ilī
# 1235    YBC 3504      Uruk                                                n/a
# 1238   YBC 17067      Uruk                  Murānu/Nabû-šūzibanni//Esaggilāya
# 1233    NBC 6172    Sippar                                   Bēl-iddin/Balāṭu
# 1239    YBC 3508      Uruk                         [Bēl-zēri?]/Kūnāya//Bā’iru
# 1234    NCBT 540      Uruk                              Pir’u/Eanna-šumu-ibni
# 1240   YOS 19 44     Larsa                            Nidintu/Nabû-šumu-iddin
# 1245    JCS 36 7      Uruk                           Nabû-balāssu-iqbi/Šumāya
# 1242    BM 42332    Sippar               Iddin-Nabû/Nabû-balāssu-iqbi//Balīhu
# 1243    YOS 7 28      Uruk                          Gimillu/Inanna-zēru-iddin
# 1244     BE 9 49    Nippur                           Ninurta-nāṣir/Arad-Enlil
# 1232  YOS 21 201      Uruk                              Šamaš-udammiqHabaṣīru
# 1246    JCS 36 4      Uruk                                        Ērišu/Šapik
# 1248    NBC 4650    Nippur                            Enlil-uballiṭ/Šumu-ukīn
# 1241    BM 27849  Borsippa                      Nabû-ušallim/Rēmūt/Ilšu-abūšu
# 1231    YBC 4047      Uruk                              Nabû-nāṣir/Ibni-Ištar
# 1226  YOS 21 209      Uruk                                                NaN
# 1229    YBC 3527     Larsa                        Šamaš-mukīn-apli/Taqīš-Gula
# 1214  YOS 17 286      Uruk              Ṣillāya/Innin-šumu-uṣur//Kidin-Marduk
# 1215    NCBT 524      Uruk                           Gimillu/Innin-zēru-iddin
# ...          ...       ...                                                ...
# 4526  YOS 17 302      Uruk                              Pir’u/Eanna-šumu-ibni
# 4542    JCS 36 4      Uruk                                        Ērišu/Šapik
# 4541    YOS 7 28      Uruk                          Gimillu/Inanna-zēru-iddin
# 4525    YBC 4047      Uruk                              Nabû-nāṣir/Ibni-Ištar
# 4539    GC 1 098      Uruk                                                n/a
# 4538   NCBT 1093      Uruk                                                n/a
# 4537   YBC 11390      Uruk                          Širikti-Marduk/Ibni-Ištar
# 4536   YBC 11390      Uruk                          Širikti-Marduk/Ibni-Ištar
# 4535    BM 25625  Borsippa  Nabû-zēru-līšir/Nabû-zēru-iddini//Iddin-Papsukkal
# 4540    BM 42332    Sippar               Iddin-Nabû/Nabû-balāssu-iqbi//Balīhu
# 4533    BM 42340    Sippar                        Balāṭu/Bēl-rēmanni//Sîn-ilī
# 4527    BM 42571    Sippar                 Nidintu/Nabû-ēṭir-napšāti//Iššakku
# 4534  YOS 21 202      Uruk                                                n/a
# 4528    YBC 3530      Uruk                                                n/a
# 4550    BM 42415    Sippar                 Nidintu/Nabû-ēṭir-napšāti//Iššakku
# 4530  YOS 21 201      Uruk                              Šamaš-udammiqHabaṣīru
# 4531  YOS 21 201      Uruk                              Šamaš-udammiqHabaṣīru
# 4532    BM 78171    Sippar                                                n/a
# 4529    NBC 6169    Sippar           Nergal-ušallim/Iddin-Bēl/Sîn-karābi-išme
# 6311     BE 9 78    Nippur                         Arad-Ninurta/Upahhir-Enlil
# 6312     BRM 1 3      Uruk                                                n/a
# 6313    BM 79041    Sippar                                                n/a
# 6314   JCS 36 15      Uruk                          Eanna-šadûnu/Marduk-nāṣir
# 5623    BM 95597   Babylon                                                n/a
# 5622    NBC 6114    Nippur                        Iddin-Enlil/Enlil-zēru-ibni
# 5621  YOS 19 230      Uruk                                                n/a
# 5619    NBC 4836      Uruk                                                n/a
# 5618    BM 42336    Sippar     Bēl-uballiṭ/Nabû-šumu-līšir/Šangû-Ištar-Bābili
# 5617    JCS 36 8      Uruk          Marduk-šumu-uṣur/Nergal-nāṣir//Damqi-Addu
# 5620    AD -273B   Babylon                                                NaN
#
#              period   year   sign                                     glyph  \
# 6280             nb  562.0    HAL  777a217b-08bf-4a3e-9d56-8d833704629c.png
# 6287     achaemenid  373.0    HAL  12c02f0b-0d15-4f6d-86ac-d91772e1ca3f.png
# 6286             nb  544.0    HAL  06948e43-3080-4318-979c-809ec1de90a0.png
# 6285     achaemenid  522.0    HAL  75ff1ab1-32c2-4b1e-82d5-f61a2607ae87.png
# 6284  peri_parthian   94.0    HAL  b52067a4-ff59-4d36-8875-bd3e84193611.png
# 6283             nb  551.0    HAL  0139c8cb-6f44-48f4-8b35-fa96f0edc7f5.png
# 6282            enb  659.0    HAL  156bfb5a-2037-4350-b692-7f7fa67c0881.png
# 6281     achaemenid  370.0    HAL  dfffce1b-b263-4a36-b9b3-d3f13487eeed.png
# 6279             nb  551.0    HAL  a255d6e2-b79a-4c40-b56e-f025cb9c0454.png
# 1237             nb  545.0     BA  6ed03fc4-9dbf-4b05-8cde-8ffa40780b7a.png
# 1236             nb  570.0     BA  6c09b38b-ad61-4776-8c6d-a803f37fa8ba.png
# 1235             nb  562.0     BA  20d7a7d9-7460-405f-98cb-fb9a381c0f44.png
# 1238             nb  542.0     BA  d10577da-b93e-4696-b4cb-8a2048890072.png
# 1233     achaemenid  528.0     BA  0cc8a492-28f1-4d1b-b3a7-42c2c147857b.png
# 1239     achaemenid  518.0     BA  bb0367df-b742-450b-b785-b89d3d4eba14.png
# 1234     achaemenid  532.0     BA  afa21de6-24cd-4692-bdb7-942b7b34c48d.png
# 1240             nb  546.0     BA  7d183c82-93e5-4b89-8950-e9cb437c66d3.png
# 1245            enb  641.0     BA  2e1766a1-1c2d-4184-80f3-713698a26eaf.png
# 1242     achaemenid  502.0     BA  7b04a61d-da69-4a92-b447-afdcd25b50e6.png
# 1243     achaemenid  535.0     BA  8b0077fc-cd91-45e9-8c84-dd7e7200d1bd.png
# 1244     achaemenid  429.0     BA  80a607c8-2029-4e97-9782-bdeb31b7d573.png
# 1232     achaemenid  503.0     BA  87fa70c2-aa73-4560-b229-82a5f080cda8.png
# 1246            enb  638.0     BA  cf2e7e39-225e-4207-90e5-f44d44835512.png
# 1248     achaemenid  534.0     BA  b029d433-e5d8-433b-8a46-f0a85a92b543.png
# 1241             nb  486.0     BA  b5616ece-3fb8-4e29-a1b6-d309c283d1fd.png
# 1231            enb  635.0     BA  abd6977b-afcb-4fb7-8119-2fea7fdccc95.png
# 1226     achaemenid  521.0     BA  d8e3af9f-6b40-40fb-9bc4-599670823210.png
# 1229             nb  566.0     BA  2595cf48-c653-4cc2-8d45-1e9e2514b130.png
# 1214     achaemenid  521.0     BA  bfc09d86-b4e7-4ac9-8164-50afb9e5de4b.png
# 1215     achaemenid  528.0     BA  3dfc8ccf-8358-4dde-9111-d922c0a6483a.png
# ...             ...    ...    ...                                       ...
# 4526  peri_parthian  521.0     NI  07c335bc-960d-4491-8d6c-10c4a90d1b06.png
# 4542            enb  638.0     NI  72118f8f-1a07-4375-b022-a598619f7f92.png
# 4541     achaemenid  535.0     NI  2df585db-9903-48b3-b091-1daac688668e.png
# 4525            enb  635.0     NI  fbfff01d-4971-421a-a2dc-9f8cd6c97c5a.png
# 4539             nb  568.0     NI  137ffcee-2e63-4a69-97ae-e1b757e77e36.png
# 4538            enb  628.0     NI  623d32b7-b60c-41e8-b902-3419f8898094.png
# 4537            enb  659.0     NI  9a333a4c-fcfb-45a8-a5e0-661bfa238816.png
# 4536            enb  659.0     NI  31ef5a92-b5b4-488c-b011-4a8d8c5918d1.png
# 4535             nb  545.0     NI  0b16bcaf-9baa-4132-9a43-2250f66b690b.png
# 4540     achaemenid  502.0     NI  a33fc73e-7de3-4073-8191-98aa7217cac9.png
# 4533             nb  570.0     NI  7ad73e4c-d123-4e4c-9b36-85734547e7d0.png
# 4527     achaemenid  511.0     NI  6a347558-ab56-49a6-a4be-9f48e0efe08f.png
# 4534     achaemenid  493.0     NI  d1ef2385-2625-47c7-b84e-df4a70e88e53.png
# 4528             nb  568.0     NI  cc7e589a-8f35-4b39-9bc8-e8c5db0991e7.png
# 4550     achaemenid  511.0     NI  25b5dd68-d2b4-4bca-a44e-0f9d06c3587a.png
# 4530     achaemenid  503.0     NI  4d8a2e81-6edb-4da3-9a9e-48e2098a7ca7.png
# 4531     achaemenid  503.0     NI  3e12ed33-508e-47ba-ae73-a464f6677b11.png
# 4532            enb  625.0     NI  832a8181-216f-48a4-83f4-c4c830c2ec75.png
# 4529     achaemenid  518.0     NI  400de334-9e23-450a-9d29-dd911a53926c.png
# 6311     achaemenid  425.0  NIGIN  706a129a-8fbf-4e3d-8b34-95383f7adc30.png
# 6312             nb  748.0  NIGIN  1ef90a4f-9795-4525-b680-50c7dda03b44.png
# 6313             nb  625.0  NIGIN  725fbb69-df34-4474-b242-9704a712c91d.png
# 6314            enb  638.0  NIGIN  d476931a-3d05-4689-afa3-396cbad2af0b.png
# 5623  peri_seleukid  372.0    PAD  6578d842-9f14-432e-9892-38efd4b16ae1.png
# 5622     achaemenid  530.0    PAD  bcf6347d-8650-43a4-b133-fb6fc6694fb8.png
# 5621             nb  552.0    PAD  9decd7a1-a4ff-4bbe-8ee3-099b96b8b8f4.png
# 5619             nb  558.0    PAD  0a3f781e-225c-4a32-9a34-5dc858a29a15.png
# 5618     achaemenid  520.0    PAD  c60630c2-3caf-47c8-82f6-668cfcd43074.png
# 5617            enb  642.0    PAD  45932423-537e-46ae-bbb3-0e62c0065f27.png
# 5620  peri_seleukid    NaN    PAD  a1f26f91-af03-4d65-b833-4cfa00af9d40.png
#
#             std_sign
# 6280    sign_002.bmp
# 6287    sign_002.bmp
# 6286    sign_002.bmp
# 6285    sign_002.bmp
# 6284    sign_002.bmp
# 6283    sign_002.bmp
# 6282    sign_002.bmp
# 6281    sign_002.bmp
# 6279    sign_002.bmp
# 1237    sign_005.bmp
# 1236    sign_005.bmp
# 1235    sign_005.bmp
# 1238    sign_005.bmp
# 1233    sign_005.bmp
# 1239    sign_005.bmp
# 1234    sign_005.bmp
# 1240    sign_005.bmp
# 1245    sign_005.bmp
# 1242    sign_005.bmp
# 1243    sign_005.bmp
# 1244    sign_005.bmp
# 1232    sign_005.bmp
# 1246    sign_005.bmp
# 1248    sign_005.bmp
# 1241    sign_005.bmp
# 1231    sign_005.bmp
# 1226    sign_005.bmp
# 1229    sign_005.bmp
# 1214    sign_005.bmp
# 1215    sign_005.bmp
# ...              ...
# 4526     sign_NI.bmp
# 4542     sign_NI.bmp
# 4541     sign_NI.bmp
# 4525     sign_NI.bmp
# 4539     sign_NI.bmp
# 4538     sign_NI.bmp
# 4537     sign_NI.bmp
# 4536     sign_NI.bmp
# 4535     sign_NI.bmp
# 4540     sign_NI.bmp
# 4533     sign_NI.bmp
# 4527     sign_NI.bmp
# 4534     sign_NI.bmp
# 4528     sign_NI.bmp
# 4550     sign_NI.bmp
# 4530     sign_NI.bmp
# 4531     sign_NI.bmp
# 4532     sign_NI.bmp
# 4529     sign_NI.bmp
# 6311  sign_NIGIN.bmp
# 6312  sign_NIGIN.bmp
# 6313  sign_NIGIN.bmp
# 6314  sign_NIGIN.bmp
# 5623    sign_PAD.bmp
# 5622    sign_PAD.bmp
# 5621    sign_PAD.bmp
# 5619    sign_PAD.bmp
# 5618    sign_PAD.bmp
# 5617    sign_PAD.bmp
# 5620    sign_PAD.bmp
#
# [6471 rows x 8 columns]

# %%
#count number of glyphs
print("number of glyphs: ", df2.shape[0])

#create table of number of glyphs per sign
df10 = df9.set_index(["tablet", "region", "period", "year", "sign", "std_sign"]).count(level="std_sign")
df10.to_csv('glyph_count.csv')
df11 = pd.read_csv('/Volumes/IMVDrive/cfdb-django/glyph_count.csv', engine='python')
df12 = df11.merge(df3, left_on='std_sign', right_on='image', how='right')
df12 = df12.drop(['image', 'scribe'], axis=1)

#count number of signs
df13 = df12.count(axis=0)
print("number of signs: ", df13[0])
print("")
# Out:
# number of glyphs:  6494
# number of signs:  235

# %%
#plot number of glyphs per sign
# %matplotlib inline
df12 = df12.sort_values(by=['glyph'])
df12.iloc[200:235].plot(x='sign_name', y='glyph', kind='bar', figsize=[35,12], title = 'glyphs per sign (significant)')

# %%
#print number of glyphs per sign
print(df12)
# Out:
#             std_sign  glyph sign_name
# 125     sign_353.bmp      0        ŠA
# 11      sign_054.bmp      1    BURU14
# 196     sign_560.bmp      1     NAGAR
# 197     sign_563.bmp      1       NIK
# 37      sign_109.bmp      1       LÀL
# 134     sign_373.bmp      1       SUD
# 176     sign_480.bmp      1       DIŠ
# 40      sign_113.bmp      1       SU4
# 206     sign_583.bmp      1     EDURU
# 128     sign_356.bmp      1       SA6
# 62   sign_151544.bmp      1     AŠGAB
# 92      sign_255.bmp      1        ÙR
# 91      sign_252.bmp      1     SILA4
# 90      sign_237.bmp      1       AMA
# 158     sign_434.bmp      1       TÙM
# 71      sign_176.bmp      1     NÍNDA
# 156     sign_430.bmp      1      GIR4
# 154     sign_425.bmp      1       KIŠ
# 117     sign_336.bmp      2       LIL
# 43      sign_122.bmp      2        ÙZ
# 76      sign_203.bmp      2        ÚR
# 34      sign_103.bmp      2       MÙŠ
# 177     sign_483.bmp      2       KIL
# 64      sign_153.bmp      2       BÀD
# 17      sign_067.bmp      2       GIL
# 22      sign_076.bmp      2       MÁŠ
# 179     sign_494.bmp      2        U8
# 193     sign_558.bmp      2      GÉME
# 180     sign_513.bmp      2     GARIM
# 198     sign_564.bmp      3        EL
# ..               ...    ...       ...
# 115     sign_334.bmp     66        ID
# 12      sign_058.bmp     67        TU
# 188     sign_545.bmp     67        ŠÚ
# 144     sign_396.bmp     68        HE
# 83      sign_214.bmp     68        BI
# 100     sign_308.bmp     69         E
# 109     sign_324.bmp     69       BIT
# 20      sign_073.bmp     69        TI
# 78      sign_206.bmp     70        DU
# 116     sign_335.bmp     70        DA
# 53      sign_139.bmp     72        TA
# 211     sign_597.bmp     73        ŠÁ
# 139     sign_381.bmp     75        UD
# 205     sign_579.bmp     76         A
# 132     sign_371.bmp     76        BU
# 126     sign_354.bmp     77        ŠU
# 10      sign_052.bmp     79       ITU
# 185     sign_537.bmp     79        LU
# 1       sign_005.bmp     81        BA
# 232      sign_NI.bmp     83        NI
# 165     sign_449.bmp     86        ŠI
# 189      sign_55.bmp     88        LA
# 27      sign_084.bmp     91        RI
# 119     sign_342.bmp     91        MA
# 54      sign_142.bmp     92         I
# 15      sign_061.bmp     95        MU
# 105     sign_318.bmp    112         Ú
# 183     sign_533.bmp    121       MEŠ
# 19      sign_070.bmp    130       NaN
# 170     sign_461.bmp    150        KI
#
# [235 rows x 3 columns]

# %%
#tablet data: number of tablets, glyphs per tablet, signs per tablet

df15 = df9.sort_values(by=['tablet', 'std_sign'])
df16 = df15.groupby(['tablet']).nunique()
df16 = df16.drop(['tablet', 'region', 'period', 'year', 'sign', 'scribe'], axis=1)
print("number of tablets: ", df16.count(axis=0)[1])
print("")
print(df16)

# %matplotlib inline
df16.to_csv('glyphs_per_tablet.csv')
df16 = pd.read_csv('/Volumes/IMVDrive/cfdb-django/glyphs_per_tablet.csv', engine='python')
df16 = df16.sort_values(by=['glyph'])
df16.iloc[250:352].plot(x='tablet', y='glyph', kind='bar', figsize=[35,12], title = 'glyphs per tablet (significant)')

print("mean glyphs per tablet: ", df16['glyph'].mean())
print("min glyphs per tablet: ", df16['glyph'].min())
print("max glyphs per tablet: ", df16['glyph'].max())
print("")
print("mean signs per tablet: ", df16['std_sign'].mean())
print("min signs per tablet: ", df16['std_sign'].min())
print("max signs per tablet: ", df16['std_sign'].max())
# Out:
# number of tablets:  352
#
#              glyph  std_sign
# tablet
# AD -105A        32        31
# AD -132B        65        56
# AD -134         12        12
# AD -137A        45        41
# AD -137D        49        45
# AD -140C        66        53
# AD -144         49        43
# AD -155A        29        28
# AD -162         22        22
# AD -168A        73        62
# AD -171B        12        12
# AD -183A        25        24
# AD -204C        14        14
# AD -226A        20        20
# AD -261B         8         8
# AD -266A        12         9
# AD -270B        27        27
# AD -273B        25        25
# AD -328         14        14
# AD -330A+B      51        49
# AD -362         21        21
# AD -366A        24        22
# AD -95C         42        40
# AD -96A         28        26
# AD -99B         19        18
# AOAT 358 52     15        15
# BCHP 11         51        43
# BCHP 14         27        27
# BCHP 17         62        51
# BCHP 18        141        93
# ...            ...       ...
# YOS 21 208       8         8
# YOS 21 209      11        11
# YOS 21 210       8         8
# YOS 21 211       9         9
# YOS 21 212      10        10
# YOS 21 213       6         6
# YOS 21 214       8         9
# YOS 21 216      14        14
# YOS 21 217       7         7
# YOS 21 218       4         4
# YOS 21 219       6         6
# YOS 6 100       18        18
# YOS 6 155       12        12
# YOS 6 159       32        32
# YOS 6 171       26        24
# YOS 6 238       15        15
# YOS 6 52        19        18
# YOS 6 64        25        24
# YOS 7 102       22        22
# YOS 7 110       32        31
# YOS 7 129       25        25
# YOS 7 154       29        29
# YOS 7 157       26        26
# YOS 7 174       30        30
# YOS 7 189       46        43
# YOS 7 196       25        25
# YOS 7 28        26        26
# YOS 7 49        26        26
# YOS 7 92        13        13
# YOS 9 82        33        32
#
# [352 rows x 2 columns]
# mean glyphs per tablet:  17.6676136364
# min glyphs per tablet:  1
# max glyphs per tablet:  141
#
# mean signs per tablet:  16.7755681818
# min signs per tablet:  1
# max signs per tablet:  93

# %%
#scribe data:

df17 = df9.groupby(['scribe']).nunique()
df17 = df17.drop(['scribe', 'period', 'year', 'sign'], axis=1)
df17.rename(index=str, columns={"image": "std_sign"})
 
#print(df17)
print("number of scribes: ", df17.count(axis=0)[1])
print("")

# %matplotlib inline
df17.to_csv('glyphs_per_scribe.csv')
df17x = pd.read_csv('/Volumes/IMVDrive/cfdb-django/glyphs_per_scribe.csv', engine='python')
df17x = df17x.sort_values(by=['glyph'])
df17x.iloc[125:167].plot(x='scribe', y='glyph', kind='bar', figsize=[35,12], title = 'glyphs per scribe (significant)')

df18 = df17.drop(['n/a', 'n/e'])
print("mean glyphs per scribe: ", df18['glyph'].mean())
print("min glyphs per scribe: ", df18['glyph'].min())
print("max glyphs per scribe: ", df18['glyph'].max())
print("")
print("mean tablets per scribe: ", df18['tablet'].mean())
print("min tablets per scribe: ", df18['tablet'].min())
print("max tabets per scribe: ", df18['tablet'].max())
# Out:
# number of scribes:  168
#
# mean glyphs per scribe:  21.4277108434
# min glyphs per scribe:  1
# max glyphs per scribe:  153
#
# mean tablets per scribe:  1.15662650602
# min tablets per scribe:  1
# max tabets per scribe:  4

# %%
df19 = df9.groupby(['period']).nunique()
df19 = df19.drop(['period', 'scribe', 'year', 'sign'], axis=1)
df19.rename(index=str, columns={"image": "std_sign"})
df19 = df19.sort_values(by=['glyph'])
print(df19)
df19.to_csv('period_table.csv')
df19 = pd.read_csv('/Volumes/IMVDrive/cfdb-django/period_table.csv', engine='python')
df19.plot(x='period', y='glyph', kind='bar', figsize=[35,12], title = 'period data (significant)')
# Out:
#                        tablet  region  glyph  std_sign
# period
# peri_earlyhellenistic       1       1     14        14
# peri_parthian              12       2    541       148
# peri_seleukid              19       1    590       145
# enb                        40       3    845       171
# nb                        112       6   1818       209
# achaemenid                159       5   2309       222

# %%
print("mean glyphs per period: ", df19['glyph'].mean())
print("min glyphs per period: ", df19['glyph'].min())
print("max glyphs per period: ", df19['glyph'].max())
print("")
print("mean tablets per period: ", df19['tablet'].mean())
print("min tablets per period: ", df19['tablet'].min())
print("max tabets per period: ", df19['tablet'].max())
print("")
print("mean std_signs per period: ", df19['std_sign'].mean())
print("min std_signs per period: ", df19['std_sign'].min())
print("max std_signs per period: ", df19['std_sign'].max())
# Out:
# mean glyphs per period:  1019.5
# min glyphs per period:  14
# max glyphs per period:  2309
#
# mean tablets per period:  57.1666666667
# min tablets per period:  1
# max tabets per period:  159
#
# mean std_signs per period:  151.5
# min std_signs per period:  14
# max std_signs per period:  222

# %%
###preparing tables for cnn
df_for_cnn1 = df9.drop(['tablet', 'region', 'scribe', 'period', 'year', 'std_sign'], axis=1)
df_for_cnn1.to_csv('glyphs-aligned-w-std_sign-images.csv')
